# %%
import pandas as pd
import numpy as np
import statistics

# %%
# find files
schools = "Resources/schools_complete.csv"
students = "Resources/students_complete.csv"

#read files
school_df = pd.read_csv(schools)
student_df = pd.read_csv(students)

school_data_all = pd.merge(student_df, school_df, how = 'left', on = 'school_name')

school_data_all.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
school_data = school_df[["school_name", "type", "size", "budget"]]
school_df
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
budget_per_student = school_data["budget"]/school_data["size"]
school_data["Per Student Budget"] = budget_per_student

by_school = school_data_all.groupby("School ID")

avg_math = by_school["math_score"].mean()
avg_read = by_school["reading_score"].mean()

school_data["Average Math Score"] = avg_math
school_data["Average Reading Score"] = avg_read

passing_math = school_data_all.loc[school_data_all["math_score"] >= 70]
passing_reading = school_data_all.loc[school_data_all["reading_score"] >= 70]


num_passing_math = passing_math.groupby("School ID")["math_score"].count()
percent_passing_math = num_passing_math/school_data["size"]

num_passing_reading= passing_reading.groupby("School ID")["reading_score"].count()
percent_passing_reading = num_passing_reading/school_data["size"]

school_data["% Passing Math"] = percent_passing_math
school_data["% Passing Reading"] = percent_passing_reading

overall_passing_rate = (percent_passing_math + percent_passing_reading)/2
school_data["Overall Passing Rate"] = overall_passing_rate

school_data
# Out:
#               school_name      type  size   budget  Per Student Budget  \
# 0       Huang High School  District  2917  1910635               655.0
# 1    Figueroa High School  District  2949  1884411               639.0
# 2     Shelton High School   Charter  1761  1056600               600.0
# 3   Hernandez High School  District  4635  3022020               652.0
# 4     Griffin High School   Charter  1468   917500               625.0
# 5      Wilson High School   Charter  2283  1319574               578.0
# 6     Cabrera High School   Charter  1858  1081356               582.0
# 7      Bailey High School  District  4976  3124928               628.0
# 8      Holden High School   Charter   427   248087               581.0
# 9        Pena High School   Charter   962   585858               609.0
# 10     Wright High School   Charter  1800  1049400               583.0
# 11  Rodriguez High School  District  3999  2547363               637.0
# ...

# %%
# table update
school_size = school_data[["size",
                              "Average Math Score", "Average Reading Score",
                              "% Passing Math", "% Passing Reading", "Overall Passing Rate"]]

school_size
# Out:
#     size  Average Math Score  Average Reading Score  % Passing Math  \
# 0   2917           76.629414              81.182722        0.656839
# 1   2949           76.711767              81.158020        0.659885
# 2   1761           83.359455              83.725724        0.938671
# 3   4635           77.289752              80.934412        0.667530
# 4   1468           83.351499              83.816757        0.933924
# 5   2283           83.274201              83.989488        0.938677
# 6   1858           83.061895              83.975780        0.941335
# 7   4976           77.048432              81.033963        0.666801
# 8    427           83.803279              83.814988        0.925059
# 9    962           83.839917              84.044699        0.945946
# 10  1800           83.682222              83.955000        0.933333
# 11  3999           76.842711              80.744686        0.663666
# 12  4761           77.072464              80.966394        0.660576
# ...

# %%
print(school_size["size"].max())
print(school_size["size"].min())
# Out:
# 4976
# 427

# %%
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

school_size["School Size"] = pd.cut(school_size["size"],
                                size_bins, labels = group_names)

school_size
# Out:
# C:\Users\jazmi\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#     size  Average Math Score  Average Reading Score  % Passing Math  \
# 0   2917           76.629414              81.182722        0.656839
# 1   2949           76.711767              81.158020        0.659885
# 2   1761           83.359455              83.725724        0.938671
# 3   4635           77.289752              80.934412        0.667530
# 4   1468           83.351499              83.816757        0.933924
# 5   2283           83.274201              83.989488        0.938677
# 6   1858           83.061895              83.975780        0.941335
# 7   4976           77.048432              81.033963        0.666801
# ...

# %%
binned_size = school_size.groupby("School Size")

binned_size["Average Math Score", "Average Reading Score", "% Passing Math", "% Passing Reading", "Overall Passing Rate"].mean()
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843        0.935502
# Medium (1000-2000)           83.374684              83.864438        0.935997
# Large (2000-5000)            77.746417              81.344493        0.699634
#
#                     % Passing Reading  Overall Passing Rate
# School Size
# Small (<1000)                0.960994              0.948248
# Medium (1000-2000)           0.967907              0.951952
# Large (2000-5000)            0.827666              0.763650
